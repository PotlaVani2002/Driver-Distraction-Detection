# %%
import os
import pandas as pd
import pickle
import shutil
import numpy as np
import seaborn as sns
from sklearn.datasets import load_files
from tensorflow.python.keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from tensorflow.python.keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

from PIL import ImageFile   
from sklearn.model_selection import train_test_split
from keras.preprocessing import image                  
from tqdm import tqdm

from keras.applications.vgg16 import VGG16
# Out:
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
TEST_DIR = os.path.join(os.getcwd(),"imgs","test")
TRAIN_DIR = os.path.join(os.getcwd(),"imgs","train")
MODEL_PATH = os.path.join(os.getcwd(),"model","vgg16_modified")
PICKLE_PATH = os.path.join(os.getcwd(),"pickle")
TEST_CSV = os.path.join(os.getcwd(),"csv_files","test.csv")
TRAIN_CSV = os.path.join(os.getcwd(),"csv_files","train.csv")

# %%
if not os.path.exists(TEST_DIR):
    print("Testing data does not exists")
if not os.path.exists(TRAIN_DIR):
    print("Training data does not exists")
if not os.path.exists(MODEL_PATH):
    print("Model path does not exists")
    os.makedirs(MODEL_PATH)
    print("Model path created")
else:
    shutil.rmtree(MODEL_PATH)
    os.makedirs(MODEL_PATH)
if not os.path.exists(PICKLE_PATH):
    os.makedirs(PICKLE_PATH)
# Out:
# Model path does not exists
# Model path created

# %%
def create_csv(DATA_DIR,filename):
    class_names = os.listdir(DATA_DIR)
    data = list()
    if(os.path.isdir(os.path.join(DATA_DIR,class_names[0]))):
        for class_name in class_names:
            file_names = os.listdir(os.path.join(DATA_DIR,class_name))
            for file in file_names:
                data.append({
                    "Filename":os.path.join(DATA_DIR,class_name,file),
                    "ClassName":class_name
                })
    else:
        class_name = "test"
        file_names = os.listdir(DATA_DIR)
        for file in file_names:
            data.append(({
                "FileName":os.path.join(DATA_DIR,file),
                "ClassName":class_name
            }))
    data = pd.DataFrame(data)
    data.to_csv(os.path.join(os.getcwd(),"csv_files",filename),index=False)

create_csv(TRAIN_DIR,"train.csv")
create_csv(TEST_DIR,"test.csv")

# %%
data_train = pd.read_csv(os.path.join(os.getcwd(),"csv_files","train.csv"))
data_test = pd.read_csv(os.path.join(os.getcwd(),"csv_files","test.csv"))

# %%
data_train = pd.read_csv(TRAIN_CSV)
data_test = pd.read_csv(TEST_CSV)

# %%
labels_list = list(set(data_train['ClassName'].values.tolist()))
labels_id = {label_name:id for id,label_name in enumerate(labels_list)}
print(labels_id)
data_train['ClassName'].replace(labels_id,inplace=True)

labels = to_categorical(data_train['ClassName'])
print(labels.shape)

with open(os.path.join(PICKLE_PATH,"labels_list_vgg16_modified.pkl"),"wb") as handle:
    pickle.dump(labels_id,handle)
# Out:
# {'c6': 0, 'c7': 1, 'c5': 2, 'c1': 3, 'c9': 4, 'c4': 5, 'c0': 6, 'c3': 7, 'c2': 8, 'c8': 9}
# (21034, 10)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18124\642161315.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_train['ClassName'].replace(labels_id,inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18124\642161315.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_train['ClassName'].replace(labels_id,inplace=True)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data_train.iloc[:,0],labels,test_size = 0.2,random_state=42)

# %%
def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(64, 64))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# pre-process the data for Keras
train_tensors = paths_to_tensor(xtrain).astype('float32')/255 - 0.5
valid_tensors = paths_to_tensor(xtest).astype('float32')/255 - 0.5
# Out:
# 100%|██████████| 16827/16827 [04:18<00:00, 65.12it/s]
# 100%|██████████| 4207/4207 [01:03<00:00, 66.26it/s]

# %%
model = VGG16(include_top=False)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save("vgg16_model_without_top.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
train_vgg16 = model.predict(train_tensors,verbose=1)
valid_vgg16 = model.predict(valid_tensors,verbose=1)
# Out:
# 526/526 [==============================] - 347s 656ms/step
# 132/132 [==============================] - 87s 657ms/step

# %%
print("Train shape",train_vgg16.shape)
print("Validation shape",valid_vgg16.shape)
# Out:
# Train shape (16827, 2, 2, 512)
# Validation shape (4207, 2, 2, 512)

# %%
train_features = train_vgg16[0]
valid_features = valid_vgg16[0]

# %%
print("Train features shape",train_features.shape)
print("Validation features shape",valid_features.shape)
# Out:
# Train features shape (2, 2, 512)
# Validation features shape (2, 2, 512)

# %%
vgg16_model_modified = Sequential()
vgg16_model_modified.add(Flatten(input_shape=train_features.shape))
vgg16_model_modified.add(Dense(500, activation='relu',kernel_initializer='glorot_normal'))
vgg16_model_modified.add(Dropout(0.5))
vgg16_model_modified.add(Dense(10, activation='softmax',kernel_initializer='glorot_normal'))

vgg16_model_modified.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 500)               1024500
#
#  dropout (Dropout)           (None, 500)               0
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 1029510 (3.93 MB)
# Trainable params: 1029510 (3.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
vgg16_model_modified.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
filepath = os.path.join(MODEL_PATH,"distractedd-{epoch:02d}-{val_accuracy:.2f}.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',period=1)
callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
model_history = vgg16_model_modified.fit(train_vgg16,ytrain,validation_data = (valid_vgg16, ytest),epochs=50, batch_size=16, shuffle=True,callbacks=callbacks_list)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1052/1052 [==============================] - ETA: 0s - loss: 1.1814 - accuracy: 0.5926
# Epoch 1: val_accuracy improved from -inf to 0.84454, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-01-0.84.hdf5
# 1052/1052 [==============================] - 14s 11ms/step - loss: 1.1814 - accuracy: 0.5926 - val_loss: 0.5516 - val_accuracy: 0.8445
# Epoch 2/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.5917 - accuracy: 0.8032
# Epoch 2: val_accuracy improved from 0.84454 to 0.89185, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-02-0.89.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.5914 - accuracy: 0.8033 - val_loss: 0.3379 - val_accuracy: 0.8918
# Epoch 3/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.4594 - accuracy: 0.8486
# Epoch 3: val_accuracy improved from 0.89185 to 0.92584, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-03-0.93.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.4592 - accuracy: 0.8486 - val_loss: 0.2474 - val_accuracy: 0.9258
# Epoch 4/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.3781 - accuracy: 0.8794
# Epoch 4: val_accuracy did not improve from 0.92584
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.3774 - accuracy: 0.8795 - val_loss: 0.2560 - val_accuracy: 0.9249
# Epoch 5/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.3489 - accuracy: 0.8927
# Epoch 5: val_accuracy did not improve from 0.92584
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.3492 - accuracy: 0.8927 - val_loss: 0.2397 - val_accuracy: 0.9232
# Epoch 6/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.3158 - accuracy: 0.9039
# Epoch 6: val_accuracy improved from 0.92584 to 0.95603, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-06-0.96.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.3158 - accuracy: 0.9039 - val_loss: 0.1535 - val_accuracy: 0.9560
# Epoch 7/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2947 - accuracy: 0.9093
# Epoch 7: val_accuracy did not improve from 0.95603
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2950 - accuracy: 0.9092 - val_loss: 0.2566 - val_accuracy: 0.9242
# Epoch 8/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.9177
# Epoch 8: val_accuracy improved from 0.95603 to 0.95912, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-08-0.96.hdf5
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2784 - accuracy: 0.9178 - val_loss: 0.1479 - val_accuracy: 0.9591
# Epoch 9/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.2685 - accuracy: 0.9221
# Epoch 9: val_accuracy improved from 0.95912 to 0.96316, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-09-0.96.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.2683 - accuracy: 0.9221 - val_loss: 0.1331 - val_accuracy: 0.9632
# Epoch 10/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2546 - accuracy: 0.9279
# Epoch 10: val_accuracy did not improve from 0.96316
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2544 - accuracy: 0.9279 - val_loss: 0.1590 - val_accuracy: 0.9577
# Epoch 11/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.9304
# Epoch 11: val_accuracy did not improve from 0.96316
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2453 - accuracy: 0.9304 - val_loss: 0.2175 - val_accuracy: 0.9468
# Epoch 12/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.2402 - accuracy: 0.9328
# Epoch 12: val_accuracy did not improve from 0.96316
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2398 - accuracy: 0.9328 - val_loss: 0.1522 - val_accuracy: 0.9632
# Epoch 13/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2221 - accuracy: 0.9363
# Epoch 13: val_accuracy did not improve from 0.96316
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2220 - accuracy: 0.9364 - val_loss: 0.1621 - val_accuracy: 0.9586
# Epoch 14/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9404
# Epoch 14: val_accuracy improved from 0.96316 to 0.96957, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-14-0.97.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.2165 - accuracy: 0.9404 - val_loss: 0.1166 - val_accuracy: 0.9696
# Epoch 15/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2081 - accuracy: 0.9407
# Epoch 15: val_accuracy did not improve from 0.96957
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2080 - accuracy: 0.9406 - val_loss: 0.1604 - val_accuracy: 0.9624
# Epoch 16/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9431
# Epoch 16: val_accuracy did not improve from 0.96957
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.2102 - accuracy: 0.9431 - val_loss: 0.1426 - val_accuracy: 0.9648
# Epoch 17/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.2187 - accuracy: 0.9424
# Epoch 17: val_accuracy did not improve from 0.96957
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.2184 - accuracy: 0.9425 - val_loss: 0.1427 - val_accuracy: 0.9684
# Epoch 18/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.2113 - accuracy: 0.9464
# Epoch 18: val_accuracy did not improve from 0.96957
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.2112 - accuracy: 0.9463 - val_loss: 0.1647 - val_accuracy: 0.9667
# Epoch 19/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9472
# Epoch 19: val_accuracy improved from 0.96957 to 0.97100, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-19-0.97.hdf5
# 1052/1052 [==============================] - 11s 11ms/step - loss: 0.1952 - accuracy: 0.9470 - val_loss: 0.1411 - val_accuracy: 0.9710
# Epoch 20/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9516
# Epoch 20: val_accuracy improved from 0.97100 to 0.97290, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-20-0.97.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1981 - accuracy: 0.9516 - val_loss: 0.1374 - val_accuracy: 0.9729
# Epoch 21/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9530
# Epoch 21: val_accuracy did not improve from 0.97290
# 1052/1052 [==============================] - 13s 12ms/step - loss: 0.1911 - accuracy: 0.9531 - val_loss: 0.1364 - val_accuracy: 0.9729
# Epoch 22/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1905 - accuracy: 0.9524
# Epoch 22: val_accuracy improved from 0.97290 to 0.97766, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-22-0.98.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1903 - accuracy: 0.9524 - val_loss: 0.1239 - val_accuracy: 0.9777
# Epoch 23/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1787 - accuracy: 0.9537
# Epoch 23: val_accuracy did not improve from 0.97766
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1786 - accuracy: 0.9536 - val_loss: 0.1289 - val_accuracy: 0.9741
# Epoch 24/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1756 - accuracy: 0.9557
# Epoch 24: val_accuracy did not improve from 0.97766
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1754 - accuracy: 0.9557 - val_loss: 0.1057 - val_accuracy: 0.9772
# Epoch 25/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1816 - accuracy: 0.9550
# Epoch 25: val_accuracy did not improve from 0.97766
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1812 - accuracy: 0.9550 - val_loss: 0.1386 - val_accuracy: 0.9722
# Epoch 26/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1730 - accuracy: 0.9559
# Epoch 26: val_accuracy did not improve from 0.97766
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1729 - accuracy: 0.9558 - val_loss: 0.1456 - val_accuracy: 0.9703
# Epoch 27/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9581
# Epoch 27: val_accuracy did not improve from 0.97766
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1592 - accuracy: 0.9580 - val_loss: 0.1463 - val_accuracy: 0.9739
# Epoch 28/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1581 - accuracy: 0.9614
# Epoch 28: val_accuracy improved from 0.97766 to 0.97837, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-28-0.98.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1584 - accuracy: 0.9613 - val_loss: 0.1356 - val_accuracy: 0.9784
# Epoch 29/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.9593
# Epoch 29: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1679 - accuracy: 0.9594 - val_loss: 0.1156 - val_accuracy: 0.9784
# Epoch 30/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.1563 - accuracy: 0.9616
# Epoch 30: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 14s 14ms/step - loss: 0.1562 - accuracy: 0.9616 - val_loss: 0.1220 - val_accuracy: 0.9779
# Epoch 31/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9607
# Epoch 31: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1583 - accuracy: 0.9607 - val_loss: 0.1368 - val_accuracy: 0.9765
# Epoch 32/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1630 - accuracy: 0.9615
# Epoch 32: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1629 - accuracy: 0.9615 - val_loss: 0.1407 - val_accuracy: 0.9736
# Epoch 33/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1517 - accuracy: 0.9627
# Epoch 33: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1515 - accuracy: 0.9628 - val_loss: 0.1662 - val_accuracy: 0.9734
# Epoch 34/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9637
# Epoch 34: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1485 - accuracy: 0.9637 - val_loss: 0.1224 - val_accuracy: 0.9784
# Epoch 35/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9630
# Epoch 35: val_accuracy did not improve from 0.97837
# 1052/1052 [==============================] - 12s 12ms/step - loss: 0.1544 - accuracy: 0.9630 - val_loss: 0.1188 - val_accuracy: 0.9769
# Epoch 36/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9657
# Epoch 36: val_accuracy improved from 0.97837 to 0.97980, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-36-0.98.hdf5
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1414 - accuracy: 0.9657 - val_loss: 0.1282 - val_accuracy: 0.9798
# Epoch 37/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9642
# Epoch 37: val_accuracy did not improve from 0.97980
# 1052/1052 [==============================] - 12s 11ms/step - loss: 0.1516 - accuracy: 0.9642 - val_loss: 0.1918 - val_accuracy: 0.9712
# Epoch 38/50
# 1051/1052 [============================>.] - ETA: 0s - loss: 0.1497 - accuracy: 0.9654
# Epoch 38: val_accuracy improved from 0.97980 to 0.98003, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-38-0.98.hdf5
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1496 - accuracy: 0.9654 - val_loss: 0.1152 - val_accuracy: 0.9800
# Epoch 39/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9651
# Epoch 39: val_accuracy improved from 0.98003 to 0.98265, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-39-0.98.hdf5
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1364 - accuracy: 0.9652 - val_loss: 0.0989 - val_accuracy: 0.9826
# Epoch 40/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9690
# Epoch 40: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1322 - accuracy: 0.9690 - val_loss: 0.1380 - val_accuracy: 0.9758
# Epoch 41/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9680
# Epoch 41: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1327 - accuracy: 0.9680 - val_loss: 0.1386 - val_accuracy: 0.9760
# Epoch 42/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1272 - accuracy: 0.9707
# Epoch 42: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 13s 12ms/step - loss: 0.1270 - accuracy: 0.9708 - val_loss: 0.1273 - val_accuracy: 0.9800
# Epoch 43/50
# 1048/1052 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9696
# Epoch 43: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1299 - accuracy: 0.9695 - val_loss: 0.1378 - val_accuracy: 0.9788
# Epoch 44/50
# 1052/1052 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9700
# Epoch 44: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1399 - accuracy: 0.9700 - val_loss: 0.1548 - val_accuracy: 0.9750
# Epoch 45/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1284 - accuracy: 0.9701
# Epoch 45: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 13s 13ms/step - loss: 0.1282 - accuracy: 0.9702 - val_loss: 0.1257 - val_accuracy: 0.9805
# Epoch 46/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1420 - accuracy: 0.9697
# Epoch 46: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 14s 13ms/step - loss: 0.1421 - accuracy: 0.9696 - val_loss: 0.1188 - val_accuracy: 0.9805
# Epoch 47/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1285 - accuracy: 0.9709
# Epoch 47: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 12s 12ms/step - loss: 0.1282 - accuracy: 0.9709 - val_loss: 0.1270 - val_accuracy: 0.9796
# Epoch 48/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1160 - accuracy: 0.9719
# Epoch 48: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 13s 12ms/step - loss: 0.1157 - accuracy: 0.9719 - val_loss: 0.1354 - val_accuracy: 0.9819
# Epoch 49/50
# 1049/1052 [============================>.] - ETA: 0s - loss: 0.1207 - accuracy: 0.9704
# Epoch 49: val_accuracy did not improve from 0.98265
# 1052/1052 [==============================] - 13s 12ms/step - loss: 0.1204 - accuracy: 0.9705 - val_loss: 0.1126 - val_accuracy: 0.9822
# Epoch 50/50
# 1050/1052 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9714
# Epoch 50: val_accuracy improved from 0.98265 to 0.98407, saving model to c:\Users\Lenovo\Desktop\Driver-Distraction-Detection\Training Notebooks\model\vgg16_modified\distractedd-50-0.98.hdf5
# 1052/1052 [==============================] - 12s 12ms/step - loss: 0.1250 - accuracy: 0.9714 - val_loss: 0.1047 - val_accuracy: 0.9841

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(model_history.history['loss'], color='b', label="Training loss")
ax1.plot(model_history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 75, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(model_history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(model_history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 75, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    fig.savefig(os.path.join(MODEL_PATH,"confusion_matrix.png"))
    return fig

# %%
def print_heatmap(n_labels, n_predictions, class_names):
    labels = n_labels #sess.run(tf.argmax(n_labels, 1))
    predictions = n_predictions #sess.run(tf.argmax(n_predictions, 1))

#     confusion_matrix = sess.run(tf.contrib.metrics.confusion_matrix(labels, predictions))
    matrix = confusion_matrix(labels.argmax(axis=1),predictions.argmax(axis=1))
    row_sum = np.sum(matrix, axis = 1)
    w, h = matrix.shape

    c_m = np.zeros((w, h))

    for i in range(h):
        c_m[i] = matrix[i] * 100 / row_sum[i]

    c = c_m.astype(dtype = np.uint8)

    
    heatmap = print_confusion_matrix(c, class_names, figsize=(18,10), fontsize=20)

# %%
class_names = list()
for name,idx in labels_id.items():
    class_names.append(name)
# print(class_names)
ypred = vgg16_model_modified.predict(valid_vgg16,verbose=1)
# Out:
# 132/132 [==============================] - 1s 5ms/step

# %%
print_heatmap(ytest,ypred,class_names)

# %%
ypred_class = np.argmax(ypred,axis=1)
# print(ypred_class[:10])
ytest = np.argmax(ytest,axis=1)

# %%
accuracy = accuracy_score(ytest,ypred_class)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(ytest, ypred_class,average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(ytest,ypred_class,average='weighted')
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(ytest,ypred_class,average='weighted')
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.984074
# Precision: 0.984188
# Recall: 0.984074
# F1 score: 0.984096
